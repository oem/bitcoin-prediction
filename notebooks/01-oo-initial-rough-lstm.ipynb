# %% [markdown]
# # Bitcoin Price Prediction

# %% [markdown]
# ## The Domain

# %% [markdown]
# The goal is to predict bitcoin prices, based on previously recorded prices.
#
# Although a precise prediction is desirable, predicting general trends is acceptable.

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### loading the data
#
# Source: https://blockchain.info/charts/market-price?timespan=all
#
# Downloaded on Feb 2, 2018

# %%
import pandas as pd
df = pd.read_csv('../data/all_time.csv')
df.columns = ['DATE', 'PRICE']
df.tail()
# Out:
#                      DATE         PRICE
# 1652  2018-01-22 00:00:00  10544.593333
# 1653  2018-01-24 00:00:00  11282.258333
# 1654  2018-01-26 00:00:00  10969.815000
# 1655  2018-01-28 00:00:00  11765.710000
# 1656  2018-01-30 00:00:00  10184.061667

# %% [markdown]
# There are not a lot of datapoints in this dataset, as you can see there is only a datapoint every other day.

# %% [markdown]
# #### visualizing the data
#
# There is a massive spike in december 2017 visible. The irregular tendencies of the data make it probably very hard to train a good model that is not overfitting the training set. This is only guessing at this point tho.
#
# The other thing we know is that the data is a time series. Meaning: it is a series of data points indexed in time order. This will play a large role in what kind of model we can use for prediction.

# %%
import matplotlib.pyplot as plt
import datetime as dt

# creating timestamps for the x axis
df_dates = [dt.datetime.strptime(d,'%Y-%m-%d %H:%M:%S').date() for d in df.DATE]

plt.figure(figsize=(22,12))
plt.plot(df_dates, df.PRICE, color='green', label='bitcoin prices')
plt.title('Bitcoin Prices Historical Data')
plt.ylabel('Price (US DOLLAR)')
plt.xlabel('Time')
plt.legend()
plt.show()

# %% [markdown]
# ## Model: LSTM

# %% [markdown]
# ### Why?

# %% [markdown]
# Since our data is a time series, recurrent neural networks are a natural fit.
# This is due to the chain-like nature of RNNs.
#
# RNNs loop their output back to themselves, which enables them to persist state for a while and learn based on previous learnings.
#
# Something that is great for time series data.
#
# ![RNN loop](img/rnn.png)
#
# If we unroll the loop, the chain-like nature becomes more obvious.
#
# ![RNN unrolled](img/rnn-unrolled.png)
#
# This chain-like nature shows a strong relationship to sequences and lists. RNNs are a NN architecture that naturally fits sequences and lists.

# %% [markdown]
# ### What are LSTMs?
#
# LSTMs are a special kind of RNN (that's why I was talking about RNNs so much previously).
#
# They were introduced by [Hochreiter & Schmidhuber in 1997](http://www.bioinf.jku.at/publications/older/2604.pdf).
#
# LSTMs are specifically designed to tackle a problem called "Long Term Dependency Problem".

# %% [markdown]
# #### Long Term Dependency Problem
#
# In theory, RNNs should be capable to predict, based on recent information. However, they don't seem to be able to learn once the gap between the relevant context and the point where it is needed grows too large.
#
# This problem has been explored in depth by [Hochreiter in 1991](http://people.idsia.ch/~juergen/SeppHochreiter1991ThesisAdvisorSchmidhuber.pdf).
#
# LSTMs do not have this problem, they are capable of learning long term dependencies.
#
# The main difference is that, while other RNNs just have a single layer, LSTMs have four layers, that interact with each other in a very specific way.
#
# Single layer of other RNNs:
# ![single layer rnn](img/rnn-single-layer.png)
#
# LSTMs with four layers:
# ![four layer lstm](img/lstm-four-layers.png)

# %% [markdown]
# ## Training the LSTM

# %% [markdown]
# ### Preparing the training and test set

# %% [markdown]
# #### batch size
#
# The batch size is the number of data points shown to the neural network per iteration. The weights are updated after each batch.
#
# #### time steps
#
# Time steps are the number of steps used to predict n steps. So, for example, use 20 steps to predict 20 steps.
#
# This is the range the LSTM is aware of for its context.
#
# #### epochs
#
# Epochs are the number times the neural network sees each data point. So, the number of times it goes through the whole training set.
#
# #### training set length
#
# The length of the training set must be dividable without a remainder by the batch size.
#
# #### test set length
#
# 20% of the data set is a usable percentage in most cases. We go with that and adjust along the way if necessary.

# %%
BATCH_SIZE = 64
EPOCHS = 220
TIME_STEPS = 30

TEST_SIZE = 0.2

# %%
def calc_training_set_length(length, batch_size, test_percent):
    length *= 1 - test_percent # reserving part of the data set for testing later on
    return(int(length - (length % batch_size)))

# %%
def calc_test_length(length, batch_size, time_steps, padded_training_size):
    length -= time_steps * 2
    length -= padded_training_size
    return(int(length - (length % batch_size)))

# %%
training_set_length = calc_training_set_length(len(df), BATCH_SIZE, TEST_SIZE)

# %% [markdown]
# we need to add a bit of padding to the end of the training set, otherwise it would go out of scope when it steps through the last bit of the training set.
#
# ![training set padding](img/padding.png)

# %%
train_with_padding = training_set_length + TIME_STEPS * 2
df_train = df[0:train_with_padding]
training_set = df_train.iloc[:,1:].values

# %% [markdown]
# #### Feature scaling
#
# Feature scaling is quite important for a lot of ANNs. If we do not scale our features they will easily saturate our first hidden layer from the beginning. When an error gets backpropagated to a saturated neuron it gets blocked from propagating further. Which means that the weights will not really be trained, or much slower, causing the ANN to converge much much slower.

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
scaled_training_set = sc.fit_transform(training_set)

# %% [markdown]
# We are now finally building our training set. First we build an array of arrays with the length we calculated before.
# The "inside" arrays are of length TIME_STEPS. The only difference between X and y is that when looking at the same index on both, X has the TIME_STEPS sized previous datapoints, while y has the TIME_STEPS sized following datapoints.
#
# One point to note: We will step through the data one data point at a time, so our TIMESTEPS * 2 window of datapoints "moves" one by one.
#
# ![training set window](img/training-set-window.png)

# %%
X_train = []
y_train = []

for i in range(TIME_STEPS, training_set_length + TIME_STEPS):
    X_train.append(scaled_training_set[i - TIME_STEPS:i, 0])
    y_train.append(scaled_training_set[i:i + TIME_STEPS, 0])

# %% [markdown]
# After we build up our data, we need to reshape it into something that can be used to train our LSTM.
#
# We just need to reshape it from our array of arrays into [training_set_length, TIME_STEPS, vector]

# %%
import numpy as np
import pandas as pd
from keras.preprocessing import sequence
from keras.models import load_model

X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))
print(X_train.shape)
print(y_train.shape)
# Out:
# /Users/oem/.pyenv/versions/3.6.3/envs/bitcoin-prediction/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# (1280, 30, 1)
# (1280, 30, 1)

# %% [markdown]
# ### Train

# %%
from keras.layers import Dense
from keras.layers import Input, LSTM
from keras.models import Model

# %%
# We are using MAE as loss function
inputs_1_mae = Input(batch_shape=(BATCH_SIZE, TIME_STEPS, 1))
lstm_1_mae = LSTM(10, stateful=True, return_sequences=True)(inputs_1_mae)
lstm_2_mae = LSTM(10, stateful=True, return_sequences=True)(lstm_1_mae)

output_1_mae = Dense(units = 1)(lstm_2_mae)

regressor_mae = Model(inputs=inputs_1_mae, outputs = output_1_mae)

regressor_mae.compile(optimizer='adam', loss = 'mae')
regressor_mae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (64, 30, 1)               0
# _________________________________________________________________
# lstm_1 (LSTM)                (64, 30, 10)              480
# _________________________________________________________________
# lstm_2 (LSTM)                (64, 30, 10)              840
# _________________________________________________________________
# dense_1 (Dense)              (64, 30, 1)               11
# =================================================================
# Total params: 1,331
# Trainable params: 1,331
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Parameters
#
# PARAMETERS = 4 × LSTM outputs size × (weights LSTM inputs size + weights LSTM outputs size + 1 bias variable)

# %%
for i in range(EPOCHS):
    print("Epoch: " + str(i))
    regressor_mae.fit(X_train, y_train, shuffle=False, epochs = 1, batch_size=BATCH_SIZE)
    regressor_mae.reset_states()
# Out:
# Epoch: 0
# Epoch 1/1
# 1280/1280 [==============================] - 2s 1ms/step - loss: 0.0937
# Epoch: 1
# Epoch 1/1
# 1280/1280 [==============================] - 0s 375us/step - loss: 0.0873
# Epoch: 2
# Epoch 1/1
# 1280/1280 [==============================] - 0s 367us/step - loss: 0.0717
# Epoch: 3
# Epoch 1/1
# 1280/1280 [==============================] - 0s 368us/step - loss: 0.0503
# Epoch: 4
# Epoch 1/1
# 1280/1280 [==============================] - 0s 353us/step - loss: 0.0616
# Epoch: 5
# Epoch 1/1
# 1280/1280 [==============================] - 0s 365us/step - loss: 0.0495
# Epoch: 6
# Epoch 1/1
# 1280/1280 [==============================] - 0s 364us/step - loss: 0.0550
# Epoch: 7
# Epoch 1/1
# 1280/1280 [==============================] - 0s 356us/step - loss: 0.0479
# Epoch: 8
# Epoch 1/1
# 1280/1280 [==============================] - 0s 373us/step - loss: 0.0547
# Epoch: 9
# Epoch 1/1
# 1280/1280 [==============================] - 0s 367us/step - loss: 0.0473
# Epoch: 10
# Epoch 1/1
# 1280/1280 [==============================] - 0s 369us/step - loss: 0.0506
# Epoch: 11
# Epoch 1/1
# 1280/1280 [==============================] - 0s 373us/step - loss: 0.0468
# Epoch: 12
# Epoch 1/1
# 1280/1280 [==============================] - 0s 376us/step - loss: 0.0512
# Epoch: 13
# Epoch 1/1
# 1280/1280 [==============================] - 0s 357us/step - loss: 0.0461
# Epoch: 14
# Epoch 1/1
# 1280/1280 [==============================] - 0s 364us/step - loss: 0.0446
# Epoch: 15
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0504
# Epoch: 16
# Epoch 1/1
# 1280/1280 [==============================] - 0s 372us/step - loss: 0.0456
# Epoch: 17
# Epoch 1/1
# 1280/1280 [==============================] - 0s 373us/step - loss: 0.0442
# Epoch: 18
# Epoch 1/1
# 1280/1280 [==============================] - 0s 347us/step - loss: 0.0490
# Epoch: 19
# Epoch 1/1
# 1280/1280 [==============================] - 0s 323us/step - loss: 0.0442
# Epoch: 20
# Epoch 1/1
# 1280/1280 [==============================] - 0s 369us/step - loss: 0.0462
# Epoch: 21
# Epoch 1/1
# 1280/1280 [==============================] - 0s 374us/step - loss: 0.0478
# Epoch: 22
# Epoch 1/1
# 1280/1280 [==============================] - 0s 372us/step - loss: 0.0443
# Epoch: 23
# Epoch 1/1
# 1280/1280 [==============================] - 0s 366us/step - loss: 0.0503
# Epoch: 24
# Epoch 1/1
# 1280/1280 [==============================] - 0s 345us/step - loss: 0.0454
# Epoch: 25
# Epoch 1/1
# 1280/1280 [==============================] - 0s 374us/step - loss: 0.0436
# Epoch: 26
# Epoch 1/1
# 1280/1280 [==============================] - 0s 373us/step - loss: 0.0434
# Epoch: 27
# Epoch 1/1
# 1280/1280 [==============================] - 0s 373us/step - loss: 0.0452
# Epoch: 28
# Epoch 1/1
# 1280/1280 [==============================] - 0s 377us/step - loss: 0.0466
# Epoch: 29
# Epoch 1/1
# 1280/1280 [==============================] - 0s 375us/step - loss: 0.0428
# Epoch: 30
# Epoch 1/1
# 1280/1280 [==============================] - 0s 374us/step - loss: 0.0435
# Epoch: 31
# Epoch 1/1
# 1280/1280 [==============================] - 0s 371us/step - loss: 0.0488
# Epoch: 32
# Epoch 1/1
# 1280/1280 [==============================] - 0s 370us/step - loss: 0.0457
# Epoch: 33
# Epoch 1/1
# 1280/1280 [==============================] - 0s 373us/step - loss: 0.0429
# Epoch: 34
# Epoch 1/1
# 1280/1280 [==============================] - 0s 376us/step - loss: 0.0497
# Epoch: 35
# Epoch 1/1
# 1280/1280 [==============================] - 0s 372us/step - loss: 0.0450
# Epoch: 36
# Epoch 1/1
# 1280/1280 [==============================] - 0s 371us/step - loss: 0.0463
# Epoch: 37
# Epoch 1/1
# 1280/1280 [==============================] - 0s 373us/step - loss: 0.0425
# Epoch: 38
# Epoch 1/1
# 1280/1280 [==============================] - 0s 374us/step - loss: 0.0462
# Epoch: 39
# Epoch 1/1
# 1280/1280 [==============================] - 0s 371us/step - loss: 0.0441
# Epoch: 40
# Epoch 1/1
# 1280/1280 [==============================] - 0s 371us/step - loss: 0.0420
# Epoch: 41
# Epoch 1/1
# 1280/1280 [==============================] - 0s 370us/step - loss: 0.0472
# Epoch: 42
# Epoch 1/1
# 1280/1280 [==============================] - 0s 370us/step - loss: 0.0428
# Epoch: 43
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0429
# Epoch: 44
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0431
# Epoch: 45
# Epoch 1/1
# 1280/1280 [==============================] - 0s 346us/step - loss: 0.0421
# Epoch: 46
# Epoch 1/1
# 1280/1280 [==============================] - 0s 367us/step - loss: 0.0459
# Epoch: 47
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0434
# Epoch: 48
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0416
# Epoch: 49
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0460
# Epoch: 50
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0411
# Epoch: 51
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0454
# Epoch: 52
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0410
# Epoch: 53
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0450
# Epoch: 54
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0413
# Epoch: 55
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0409
# Epoch: 56
# Epoch 1/1
# 1280/1280 [==============================] - 0s 358us/step - loss: 0.0442
# Epoch: 57
# Epoch 1/1
# 1280/1280 [==============================] - 0s 341us/step - loss: 0.0437
# Epoch: 58
# Epoch 1/1
# 1280/1280 [==============================] - 0s 343us/step - loss: 0.0457
# Epoch: 59
# Epoch 1/1
# 1280/1280 [==============================] - 0s 335us/step - loss: 0.0409
# Epoch: 60
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0454
# Epoch: 61
# Epoch 1/1
# 1280/1280 [==============================] - 0s 356us/step - loss: 0.0408
# Epoch: 62
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0440
# Epoch: 63
# Epoch 1/1
# 1280/1280 [==============================] - 0s 366us/step - loss: 0.0417
# Epoch: 64
# Epoch 1/1
# 1280/1280 [==============================] - 0s 368us/step - loss: 0.0463
# Epoch: 65
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0427
# Epoch: 66
# Epoch 1/1
# 1280/1280 [==============================] - 0s 343us/step - loss: 0.0411
# Epoch: 67
# Epoch 1/1
# 1280/1280 [==============================] - 0s 364us/step - loss: 0.0404
# Epoch: 68
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0429
# Epoch: 69
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0429
# Epoch: 70
# Epoch 1/1
# 1280/1280 [==============================] - 0s 346us/step - loss: 0.0427
# Epoch: 71
# Epoch 1/1
# 1280/1280 [==============================] - 0s 365us/step - loss: 0.0430
# Epoch: 72
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0432
# Epoch: 73
# Epoch 1/1
# 1280/1280 [==============================] - 0s 356us/step - loss: 0.0430
# Epoch: 74
# Epoch 1/1
# 1280/1280 [==============================] - 0s 355us/step - loss: 0.0449
# Epoch: 75
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0405
# Epoch: 76
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0445
# Epoch: 77
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0403
# Epoch: 78
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0441
# Epoch: 79
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0407
# Epoch: 80
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0438
# Epoch: 81
# Epoch 1/1
# 1280/1280 [==============================] - 0s 364us/step - loss: 0.0408
# Epoch: 82
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0430
# Epoch: 83
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0418
# Epoch: 84
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0434
# Epoch: 85
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0451
# Epoch: 86
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0413
# Epoch: 87
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0422
# Epoch: 88
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0409
# Epoch: 89
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0426
# Epoch: 90
# Epoch 1/1
# 1280/1280 [==============================] - 0s 371us/step - loss: 0.0436
# Epoch: 91
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0444
# Epoch: 92
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0401
# Epoch: 93
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0436
# Epoch: 94
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0404
# Epoch: 95
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0432
# Epoch: 96
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0400
# Epoch: 97
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0402
# Epoch: 98
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0423
# Epoch: 99
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0419
# Epoch: 100
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0431
# Epoch: 101
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0398
# Epoch: 102
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0400
# Epoch: 103
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0408
# Epoch: 104
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0445
# Epoch: 105
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0418
# Epoch: 106
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0418
# Epoch: 107
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0405
# Epoch: 108
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0408
# Epoch: 109
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0443
# Epoch: 110
# Epoch 1/1
# 1280/1280 [==============================] - 0s 334us/step - loss: 0.0412
# Epoch: 111
# Epoch 1/1
# 1280/1280 [==============================] - 0s 356us/step - loss: 0.0413
# Epoch: 112
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0401
# Epoch: 113
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0398
# Epoch: 114
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0397
# Epoch: 115
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0408
# Epoch: 116
# Epoch 1/1
# 1280/1280 [==============================] - 0s 365us/step - loss: 0.0436
# Epoch: 117
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0398
# Epoch: 118
# Epoch 1/1
# 1280/1280 [==============================] - 0s 357us/step - loss: 0.0401
# Epoch: 119
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0406
# Epoch: 120
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0422
# Epoch: 121
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0435
# Epoch: 122
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0400
# Epoch: 123
# Epoch 1/1
# 1280/1280 [==============================] - 0s 368us/step - loss: 0.0435
# Epoch: 124
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0399
# Epoch: 125
# Epoch 1/1
# 1280/1280 [==============================] - 0s 364us/step - loss: 0.0428
# Epoch: 126
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0396
# Epoch: 127
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0399
# Epoch: 128
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0399
# Epoch: 129
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0406
# Epoch: 130
# Epoch 1/1
# 1280/1280 [==============================] - 0s 365us/step - loss: 0.0413
# Epoch: 131
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0415
# Epoch: 132
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0404
# Epoch: 133
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0405
# Epoch: 134
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0446
# Epoch: 135
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0423
# Epoch: 136
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0408
# Epoch: 137
# Epoch 1/1
# 1280/1280 [==============================] - 0s 347us/step - loss: 0.0436
# Epoch: 138
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0401
# Epoch: 139
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0400
# Epoch: 140
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0395
# Epoch: 141
# Epoch 1/1
# 1280/1280 [==============================] - 0s 364us/step - loss: 0.0415
# Epoch: 142
# Epoch 1/1
# 1280/1280 [==============================] - 0s 356us/step - loss: 0.0415
# Epoch: 143
# Epoch 1/1
# 1280/1280 [==============================] - 0s 358us/step - loss: 0.0413
# Epoch: 144
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0422
# Epoch: 145
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0394
# Epoch: 146
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0402
# Epoch: 147
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0406
# Epoch: 148
# Epoch 1/1
# 1280/1280 [==============================] - 0s 354us/step - loss: 0.0447
# Epoch: 149
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0425
# Epoch: 150
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0420
# Epoch: 151
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0403
# Epoch: 152
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0426
# Epoch: 153
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0406
# Epoch: 154
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0404
# Epoch: 155
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0416
# Epoch: 156
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0413
# Epoch: 157
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0443
# Epoch: 158
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0421
# Epoch: 159
# Epoch 1/1
# 1280/1280 [==============================] - 0s 364us/step - loss: 0.0425
# Epoch: 160
# Epoch 1/1
# 1280/1280 [==============================] - 0s 364us/step - loss: 0.0398
# Epoch: 161
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0396
# Epoch: 162
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0399
# Epoch: 163
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0394
# Epoch: 164
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0427
# Epoch: 165
# Epoch 1/1
# 1280/1280 [==============================] - 0s 358us/step - loss: 0.0395
# Epoch: 166
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0416
# Epoch: 167
# Epoch 1/1
# 1280/1280 [==============================] - 0s 346us/step - loss: 0.0401
# Epoch: 168
# Epoch 1/1
# 1280/1280 [==============================] - 0s 340us/step - loss: 0.0428
# Epoch: 169
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0406
# Epoch: 170
# Epoch 1/1
# 1280/1280 [==============================] - 0s 347us/step - loss: 0.0398
# Epoch: 171
# Epoch 1/1
# 1280/1280 [==============================] - 0s 350us/step - loss: 0.0431
# Epoch: 172
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0399
# Epoch: 173
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0400
# Epoch: 174
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0403
# Epoch: 175
# Epoch 1/1
# 1280/1280 [==============================] - 0s 333us/step - loss: 0.0439
# Epoch: 176
# Epoch 1/1
# 1280/1280 [==============================] - 0s 341us/step - loss: 0.0421
# Epoch: 177
# Epoch 1/1
# 1280/1280 [==============================] - 0s 353us/step - loss: 0.0417
# Epoch: 178
# Epoch 1/1
# 1280/1280 [==============================] - 0s 366us/step - loss: 0.0413
# Epoch: 179
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0412
# Epoch: 180
# Epoch 1/1
# 1280/1280 [==============================] - 0s 350us/step - loss: 0.0424
# Epoch: 181
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0393
# Epoch: 182
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0421
# Epoch: 183
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0394
# Epoch: 184
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0408
# Epoch: 185
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0408
# Epoch: 186
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0407
# Epoch: 187
# Epoch 1/1
# 1280/1280 [==============================] - 0s 358us/step - loss: 0.0410
# Epoch: 188
# Epoch 1/1
# 1280/1280 [==============================] - 0s 365us/step - loss: 0.0395
# Epoch: 189
# Epoch 1/1
# 1280/1280 [==============================] - 0s 360us/step - loss: 0.0421
# Epoch: 190
# Epoch 1/1
# 1280/1280 [==============================] - 0s 364us/step - loss: 0.0394
# Epoch: 191
# Epoch 1/1
# 1280/1280 [==============================] - 0s 359us/step - loss: 0.0396
# Epoch: 192
# Epoch 1/1
# 1280/1280 [==============================] - 0s 362us/step - loss: 0.0425
# Epoch: 193
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0392
# Epoch: 194
# Epoch 1/1
# 1280/1280 [==============================] - 0s 363us/step - loss: 0.0407
# Epoch: 195
# Epoch 1/1
# 1280/1280 [==============================] - 0s 361us/step - loss: 0.0407
# Epoch: 196
# Epoch 1/1
# 1280/1280 [==============================] - 0s 348us/step - loss: 0.0406
# Epoch: 197
# Epoch 1/1
# 1280/1280 [==============================] - 0s 366us/step - loss: 0.0410
# Epoch: 198
# Epoch 1/1
# 1280/1280 [==============================] - 0s 347us/step - loss: 0.0395
# Epoch: 199
# Epoch 1/1
# 1280/1280 [==============================] - 0s 365us/step - loss: 0.0424
# Epoch: 200
# Epoch 1/1
# 1280/1280 [==============================] - 1s 410us/step - loss: 0.0391
# Epoch: 201
# Epoch 1/1
# 1280/1280 [==============================] - 1s 466us/step - loss: 0.0412
# Epoch: 202
# Epoch 1/1
# 1280/1280 [==============================] - 1s 599us/step - loss: 0.0389
# Epoch: 203
# Epoch 1/1
# 1280/1280 [==============================] - 1s 537us/step - loss: 0.0389
# Epoch: 204
# Epoch 1/1
# 1280/1280 [==============================] - 1s 585us/step - loss: 0.0392
# Epoch: 205
# Epoch 1/1
# 1280/1280 [==============================] - 1s 652us/step - loss: 0.0394
# Epoch: 206
# Epoch 1/1
# 1280/1280 [==============================] - 1s 523us/step - loss: 0.0411
# Epoch: 207
# Epoch 1/1
# 1280/1280 [==============================] - 1s 527us/step - loss: 0.0421
# Epoch: 208
# Epoch 1/1
# 1280/1280 [==============================] - 1s 440us/step - loss: 0.0394
# Epoch: 209
# Epoch 1/1
# 1280/1280 [==============================] - 0s 376us/step - loss: 0.0409
# Epoch: 210
# Epoch 1/1
# 1280/1280 [==============================] - 1s 427us/step - loss: 0.0421
# Epoch: 211
# Epoch 1/1
# 1280/1280 [==============================] - 1s 441us/step - loss: 0.0429
# Epoch: 212
# Epoch 1/1
# 1280/1280 [==============================] - 1s 424us/step - loss: 0.0399
# Epoch: 213
# Epoch 1/1
# 1280/1280 [==============================] - 1s 479us/step - loss: 0.0400
# Epoch: 214
# Epoch 1/1
# 1280/1280 [==============================] - 1s 411us/step - loss: 0.0405
# Epoch: 215
# Epoch 1/1
# 1280/1280 [==============================] - 1s 444us/step - loss: 0.0395
# Epoch: 216
# Epoch 1/1
# 1280/1280 [==============================] - 0s 365us/step - loss: 0.0397
# Epoch: 217
# Epoch 1/1
# 1280/1280 [==============================] - 0s 390us/step - loss: 0.0428
# Epoch: 218
# Epoch 1/1
# 1280/1280 [==============================] - 1s 405us/step - loss: 0.0400
# Epoch: 219
# Epoch 1/1
# 1280/1280 [==============================] - 0s 383us/step - loss: 0.0396

# %% [markdown]
# ### Test

# %% [markdown]
# creating the test set is quite similar to creating the training set. We are also going to scale and shape the set.
#
# We are getting the largest possible data set above the padded training set that is dividable by batch size without modulo.

# %%
testset_length = calc_test_length(len(df), BATCH_SIZE, TIME_STEPS, train_with_padding)
test_with_padding = testset_length + TIME_STEPS * 2 + train_with_padding

df_test = df[train_with_padding:test_with_padding] 
test_set = df_test.iloc[:,1:].values

# %% [markdown]
# Yes, this is actually repetitive and we will very likely build a pipeline for our scaling and shaping.

# %%
scaled_test_values = sc.fit_transform(test_set)

X_test = []
for i in range(TIME_STEPS, testset_length + TIME_STEPS):
    X_test.append(scaled_test_values[i - TIME_STEPS:i, 0])
X_test = np.array(X_test)

# shaping the test set, same as with the training set
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# #### Predicions

# %%
predicted_mae = regressor_mae.predict(X_test, batch_size = BATCH_SIZE)
regressor_mae.reset_states()

print(predicted_mae.shape)

# reshaping - this should probably look familiar by now
predicted_mae = np.reshape(predicted_mae, (predicted_mae.shape[0], predicted_mae.shape[1]))

print(predicted_mae.shape)

# inverse transform
predicted_mae = sc.inverse_transform(predicted_mae)

y_test = []
for j in range(0, testset_length - TIME_STEPS):
    y_test = np.append(y_test, predicted_mae[j, TIME_STEPS - 1])

# reshaping
y_test = np.reshape(y_test, (y_test.shape[0], 1))

print(y_test.shape)
# Out:
# (256, 30, 1)
# (256, 30)
# (226, 1)

# %% [markdown]
# #### Visualize the results

# %%
# Visualising the results
dates = df[train_with_padding:test_with_padding].DATE.values
dates = dates[TIME_STEPS:len(y_test)]
dates = [dt.datetime.strptime(d,'%Y-%m-%d %H:%M:%S').date() for d in dates]
plt.figure(figsize=(22,12))
plt.plot(dates, test_set[TIME_STEPS:len(y_test)], color = 'green', label = 'real bitcoin prices')
plt.plot(dates, y_test[0:len(y_test) - TIME_STEPS], color = 'orange', label = 'predicted bitcoin')
plt.title('bitcoin price prediction - MAE')
plt.xlabel('Time')
plt.ylabel('prices')
plt.legend()
plt.show()

# %% [markdown]
# ### Measure

# %%
import math
from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(test_set[TIME_STEPS:len(y_test)], y_test[0:len(y_test) - TIME_STEPS]))
print(rmse)
# Out:
# 171.91141305041012

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(test_set[TIME_STEPS:len(y_test)], y_test[0:len(y_test) - TIME_STEPS])
print(mae)
# Out:
# 103.21850062292026

# %% [markdown]
# the RMSE is probably more interesting, since it punishes larger errors more. Which, for price predictions sound about right.

# %% [markdown]
# ## What's next?
#
# Our current model is not all that great at predicting. There are plenty of ways to optimize this, getting a better data set and using another loss function like MSE would probably be the first on the list.
#
# Once the model predictions are satisfying it should be moved from the notebook into proper code. Something that is flexible enough to predict upcoming prices on current prices and that could be easily retrained with updated data points (online learning).
